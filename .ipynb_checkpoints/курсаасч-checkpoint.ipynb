# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
df=pd.read_csv('student dropout.csv')
df.columns = df.columns.str.strip()
df
# Out:
#     School Gender  Age Address Family_Size Parental_Status  Mother_Education  \
# 0       GP      F   18       U         GT3               A                 4
# 1       GP      F   17       U         GT3               T                 1
# 2       GP      F   15       U         LE3               T                 1
# 3       GP      F   15       U         GT3               T                 4
# 4       GP      F   16       U         GT3               T                 3
# ..     ...    ...  ...     ...         ...             ...               ...
# 644     MS      F   19       R         GT3               T                 2
# 645     MS      F   18       U         LE3               T                 3
# 646     MS      F   18       U         GT3               T                 1
# 647     MS      M   17       U         LE3               T                 3
# 648     MS      M   18       R         LE3               T                 3
#
#      Father_Education Mother_Job Father_Job  ... Free_Time Going_Out  \
# 0                   4    at_home    teacher  ...         3         4
# 1                   1    at_home      other  ...         3         3
# 2                   1    at_home      other  ...         3         2
# 3                   2     health   services  ...         2         2
# 4                   3      other      other  ...         3         2
# ..                ...        ...        ...  ...       ...       ...
# 644                 3   services      other  ...         4         2
# 645                 1    teacher   services  ...         3         4
# 646                 1      other      other  ...         1         1
# 647                 1   services   services  ...         4         5
# 648                 2   services      other  ...         4         1
#
#      Weekend_Alcohol_Consumption  Weekday_Alcohol_Consumption  Health_Status  \
# 0                              1                            1              3
# 1                              1                            1              3
# 2                              2                            3              3
# 3                              1                            1              5
# 4                              1                            2              5
# ..                           ...                          ...            ...
# 644                            1                            2              5
# 645                            1                            1              1
# 646                            1                            1              5
# 647                            3                            4              2
# 648                            3                            4              5
#
#     Number_of_Absences Grade_1 Grade_2 Final_Grade Dropped_Out
# 0                    4       0      11          11       False
# 1                    2       9      11          11       False
# 2                    6      12      13          12       False
# 3                    0      14      14          14       False
# 4                    0      11      13          13       False
# ..                 ...     ...     ...         ...         ...
# 644                  4      10      11          10       False
# 645                  4      15      15          16       False
# 646                  6      11      12           9        True
# 647                  6      10      10          10       False
# 648                  4      10      11          11       False
#
# [649 rows x 34 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 34 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   School                       649 non-null    object
#  1   Gender                       649 non-null    object
#  2   Age                          649 non-null    int64
#  3   Address                      649 non-null    object
#  4   Family_Size                  649 non-null    object
#  5   Parental_Status              649 non-null    object
#  6   Mother_Education             649 non-null    int64
#  7   Father_Education             649 non-null    int64
#  8   Mother_Job                   649 non-null    object
#  9   Father_Job                   649 non-null    object
#  10  Reason_for_Choosing_School   649 non-null    object
#  11  Guardian                     649 non-null    object
#  12  Travel_Time                  649 non-null    int64
#  13  Study_Time                   649 non-null    int64
#  14  Number_of_Failures           649 non-null    int64
#  15  School_Support               649 non-null    object
#  16  Family_Support               649 non-null    object
#  17  Extra_Paid_Class             649 non-null    object
#  18  Extra_Curricular_Activities  649 non-null    object
#  19  Attended_Nursery             649 non-null    object
#  20  Wants_Higher_Education       649 non-null    object
#  21  Internet_Access              649 non-null    object
#  22  In_Relationship              649 non-null    object
#  23  Family_Relationship          649 non-null    int64
#  24  Free_Time                    649 non-null    int64
#  25  Going_Out                    649 non-null    int64
#  26  Weekend_Alcohol_Consumption  649 non-null    int64
#  27  Weekday_Alcohol_Consumption  649 non-null    int64
#  28  Health_Status                649 non-null    int64
#  29  Number_of_Absences           649 non-null    int64
#  30  Grade_1                      649 non-null    int64
#  31  Grade_2                      649 non-null    int64
#  32  Final_Grade                  649 non-null    int64
#  33  Dropped_Out                  649 non-null    bool
# dtypes: bool(1), int64(16), object(17)
# memory usage: 168.1+ KB

# %% [markdown]
# # Описание столбцов

# %% [markdown]
# Описания столбцов:
#
# Школа: название посещаемой школы (например, MS).
#
# Пол: пол учащегося (например, M — мужчина, F — женщина).
#
# Возраст: возраст учащегося.
#
# Адрес: Тип проживания (U для городского, R для сельского).
#
# Family_Size: размер семьи (GT3 — больше 3, LE3 — меньше или равно 3).
#
# Родительский_статус: условия проживания родителей (A — совместное проживание, T — раздельное проживание).
#
# Mother_Education: уровень образования матери (от 0 до 4).
#
# Образование_отца: уровень образования отца (от 0 до 4).
#
# Mother_Job: Тип работы, которую выполняет мать.
#
# Father_Job: Тип работы, которую выполняет отец.
#
# Причина_выбора_школы: причина выбора школы (например, курс).
#
# Опекун: Опекун учащегося (например, мать).
#
# Время в пути: время, затрачиваемое на дорогу до школы (в минутах).
#
# Study_Time: Еженедельные учебные часы (с 1 по 4).
#
# Number_of_Failures: количество прошлых неудач в классе.
#
# Школьная_поддержка: получает ли учащийся дополнительную образовательную поддержку (да/нет).
#
# Family_Support: Семья оказывала образовательную поддержку (да / нет).
#
# Extra_Paid_Class: участие в дополнительных платных занятиях (да/нет).
#
# Внеклассные_занятия: участие во внеклассных мероприятиях (да/нет).
#
# Посещал_детский_сад: посещение детского сада (да/нет).
#
# Желание_получить_высшее_образование: желание получить высшее образование (да/нет).
#
# Доступ к интернету: наличие интернета дома (да / нет).
#
# In_Relationship: статус романтических отношений (да / нет).
#
# Семейные_отношения: качество семейных отношений (по шкале от 1 до 5).
#
# Свободное_время: количество свободного времени после школы (по шкале от 1 до 5).
#
# Выход_в_свет: частота выходов в свет с друзьями (по шкале от 1 до 5).
#
# Потребление алкоголя в выходные: потребление алкоголя в выходные (по шкале от 1 до 5).
#
# Потребление алкоголя в будние дни: потребление алкоголя в будние дни (по шкале от 1 до 5).
#
# Состояние здоровья: оценка здоровья учащегося (по шкале от 1 до 5).
#
# Количество_пропусков: общее количество пропусков занятий в школе.
#
# Grade_1: оценка, полученная при первом оценивании.
#
# Grade_2: оценка, полученная при втором оценивании.
#
# Final_Grade: получена итоговая оценка (G3).
#
# Выбыл_из_школы: индикатор того, выбыл ли ученик из школы (истина/ложь).

# %% [markdown]
# # f

# %%
categorical_columns = df.select_dtypes(include=['object']).columns
# df = pd.get_dummies(df, columns=categorical_columns, drop_first=True)
# numeric_df = df.select_dtypes(include=[np.number])
plt.figure(figsize=(150, 100), dpi=1500)
# sns.heatmap(numeric_df.corr(), annot=True, fmt='.2f', cmap='coolwarm')
sns.heatmap(df.apply(lambda x: x.factorize()[0]).corr(), annot=True, fmt='.2f', cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ### Family_Size и Желание получить высшее образование:
# ### Внеклассные занятия и Желание получить высшее образование:
#
# ### Семейные отношения и StudyTime:
# ### Семейные отношения и Количество пропусков:
# ### Возраст и количество пропусков
# ### Возраст и Свободное время
# ### StudyTime и FinalGrade:
# ### Платые занятия и Успеваемость
# ### Семейные отношения и Финальная оценка:

# %% [markdown]
# ## Family_Size и Желание получить высшее образование:

# %%
education = df.groupby('Family_Size')['Wants_Higher_Education'].value_counts().unstack().fillna(0)

print(education)
plt.figure(figsize=(12, 6))
education.plot(kind='bar', stacked=False,color=['red','green'])
plt.title('Влияние размера семьи на желание получить высшее образование')
plt.xlabel('Размер семьи')
plt.ylabel('К')
plt.legend(title='', labels=['нет','да'])
plt.show()
# Out:
# Wants_Higher_Education  no  yes
# Family_Size
# GT3                     49  408
# LE3                     20  172
